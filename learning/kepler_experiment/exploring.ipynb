# %% [markdown]
# # Exoplanet Recovery Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.family']='serif'
plt.style.use('ggplot')

# %% [markdown]
# ## Misc. First Plots

# %%
raw_df = pd.read_csv('https://raw.githubusercontent.com/HarritonResearchLab/sunnyhills/main/learning/kepler_experiment/data/eu_exoplanet_catalog.csv')
concise_df = pd.read_csv('https://raw.githubusercontent.com/HarritonResearchLab/sunnyhills/main/learning/kepler_experiment/data/concise_df.csv')

# %%
plt.scatter(concise_df['orbital_period'], concise_df['semi_major_axis'])
#plt.xlim(0, 8)
#plt.ylim(0,300)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Orbital Period')
plt.ylabel('Orbital Distance')

plt.show()

# %%
# Create a figure and then apply the aitoff projection
plt.figure(figsize=(12, 8))
plt.subplot(projection="aitoff")

# Plot Star Locations
plt.scatter(concise_df['ra'], concise_df['dec'])

# Replace the standard x ticks (longitude) with the ecliptic coordinates
plt.xticks(ticks=np.radians([-150, -120, -90, -60, -30, 0, \
                             30, 60, 90, 120, 150]),
           labels=['150°', '120°', '90°', '60°', '30°', '0°', \
                   '330°', '300°', '270°', '240°', '210°'])

# Set the axes labels
plt.xlabel('Right Ascension (deg)')
plt.ylabel('Declination (deg)')

# Plot grid
plt.grid(True)

plt.show()

# %%
plt.hist(concise_df['radius'])
plt.xlabel('Radius')
plt.ylabel('Count')
plt.show()
